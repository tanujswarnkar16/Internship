# %%
import selenium
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
#first connect to web driver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %% [markdown]
# 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
searchjob=driver.find_element_by_id('twotabsearchtextbox')
searchjob.send_keys(input('enter the value:'))
searchbtn=driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
searchbtn.click()
# Out:
# enter the value:laptop

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver.get('https://www.amazon.in/s?k=laptop&ref=nb_sb_noss')

# %%
url=[]
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    url.append(i.get_attribute('href'))
url
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A050239413215IGNLPTBS&url=%2FAcer-AN515-57-i5-11400H-Graphics-Keyboard%2Fdp%2FB09B2F2DMK%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-1-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A02748822JFWN162D0TRN&url=%2FFujitsu-Business-Graphics-Fingerprint-4ZR1D67595%2Fdp%2FB098P1K6W9%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-2-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_atf',
#  'https://www.amazon.in/ASUS-VivoBook-Integrated-Transparent-X515MA-BR002T/dp/B08CKY5XX3/ref=sr_1_3?keywords=laptop&qid=1639377407&sr=8-3',
#  'https://www.amazon.in/Dell-35-56cms-Integrated-Graphics-D552147WIN9BE/dp/B08X4NYNHW/ref=sr_1_4?keywords=laptop&qid=1639377407&sr=8-4',
#  'https://www.amazon.in/Lenovo-IdeaPad-Celeron-Platinum-81VT0071IN/dp/B09G9ZPV38/ref=sr_1_5?keywords=laptop&qid=1639377407&sr=8-5',
#  'https://aax-eu.amazon.in/x/c/QpCnX5ulXk0UIupRW5WmU1EAAAF9soIOywMAAAH2ARVkzH4/https://www.amazon.in/dp/B09FHQQQL8?pd_rd_i=B09FHQQQL8&pd_rd_w=2ZfVo&pf_rd_p=a75ba368-11d2-4ce4-98f8-b19ed03dc54e&pd_rd_wg=endOO&pf_rd_r=WG4EWN2ETH4XMTKE7QGD&pd_rd_r=21d9fc39-566a-46a9-b56b-b999b24cd24d',
#  'https://www.amazon.in/ZenBook-UX433FA-A6106T-i5-8265U-Integrated-Graphics/dp/B07M7BZNSC/ref=sxin_13?asc_contentid=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&creativeASIN=B07M7BZNSC&cv_ct_cx=laptop&cv_ct_id=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-earns-comm&keywords=laptop&linkCode=oas&pd_rd_i=B07M7BZNSC&pd_rd_r=21d9fc39-566a-46a9-b56b-b999b24cd24d&pd_rd_w=w5Pyx&pd_rd_wg=endOO&pf_rd_p=0e89a72f-7500-4160-954f-faff18efeda5&pf_rd_r=WG4EWN2ETH4XMTKE7QGD&qid=1639377407&sr=1-1-61f4c597-7a45-4a97-bd75-c52903f8ee93&tag=technologytoday-21',
#  'https://www.amazon.in/Acer-14-inch-Display-Graphics-SF314-42/dp/B0894NHJH4/ref=sxin_13?asc_contentid=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&creativeASIN=B0894NHJH4&cv_ct_cx=laptop&cv_ct_id=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-earns-comm&keywords=laptop&linkCode=oas&pd_rd_i=B0894NHJH4&pd_rd_r=21d9fc39-566a-46a9-b56b-b999b24cd24d&pd_rd_w=w5Pyx&pd_rd_wg=endOO&pf_rd_p=0e89a72f-7500-4160-954f-faff18efeda5&pf_rd_r=WG4EWN2ETH4XMTKE7QGD&qid=1639377407&sr=1-2-61f4c597-7a45-4a97-bd75-c52903f8ee93&tag=technologytoday-21',
#  'https://www.amazon.in/HP-3-3250-Laptop-Windows-15s-gr0011AU/dp/B08T6SJ215/ref=sxin_13?asc_contentid=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&creativeASIN=B08T6SJ215&cv_ct_cx=laptop&cv_ct_id=amzn1.osa.53ed3184-dddf-4c54-a0bd-12962af0ce7f.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-earns-comm&keywords=laptop&linkCode=oas&pd_rd_i=B08T6SJ215&pd_rd_r=21d9fc39-566a-46a9-b56b-b999b24cd24d&pd_rd_w=w5Pyx&pd_rd_wg=endOO&pf_rd_p=0e89a72f-7500-4160-954f-faff18efeda5&pf_rd_r=WG4EWN2ETH4XMTKE7QGD&qid=1639377407&sr=1-3-61f4c597-7a45-4a97-bd75-c52903f8ee93&tag=technologytoday-21',
#  'https://www.amazon.in/AVITA-Cosmos-Celeron-Dual-Core/dp/B09HKBR46P/ref=sr_1_6?keywords=laptop&qid=1639377407&sr=8-6',
#  'https://www.amazon.in/HP-Chromebook-14a-na0003TU-Touchscreen-Expandable/dp/B08C5W6PL2/ref=sr_1_7?keywords=laptop&qid=1639377407&sr=8-7',
#  'https://www.amazon.in/Dell-Graphics-Inspiron-3515-D560523WIN9BE/dp/B09F3QJF4W/ref=sr_1_8?keywords=laptop&qid=1639377407&sr=8-8',
#  'https://www.amazon.in/HP-inches-Laptop-Windows-15s-du1066TU/dp/B095YC11CF/ref=sr_1_9?keywords=laptop&qid=1639377407&sr=8-9',
#  'https://www.amazon.in/Lenovo-IdeaPad-Celeron-Platinum-81WH007KIN/dp/B09MM4FPMR/ref=sr_1_10?keywords=laptop&qid=1639377407&sr=8-10',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_mtf_aps_sr_pg1_1?ie=UTF8&adId=A02756162W2OKXMOTSYYW&url=%2FHP-Pavilion-Graphics-Keyboard-14-dv0054TU%2Fdp%2FB08WBB369L%2Fref%3Dsr_1_11_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-11-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_mtf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_mtf_aps_sr_pg1_1?ie=UTF8&adId=A0920238GM3HWTBWOPYY&url=%2FHP-15-6-inch-Laptop-Windows-15s-gy0501AU%2Fdp%2FB09FL5CK19%2Fref%3Dsr_1_12_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-12-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_mtf',
#  'https://www.amazon.in/Dell-Graphics-Inspiron-3505-D560613WIN9SE/dp/B09F3NL1RT/ref=sr_1_13?keywords=laptop&qid=1639377407&sr=8-13',
#  'https://www.amazon.in/HP-inches-Business-Windows-Natural/dp/B09KLZJDT6/ref=sr_1_14?keywords=laptop&qid=1639377407&sr=8-14',
#  'https://www.amazon.in/HP-Chromebook-14a-na0002TU-Integrated-Graphics/dp/B08C5WLK3P/ref=sr_1_15?keywords=laptop&qid=1639377407&sr=8-15',
#  'https://www.amazon.in/HP-15-6-inch-Laptop-Windows-15s-gy0501AU/dp/B09FL5CK19/ref=sr_1_16?keywords=laptop&qid=1639377407&sr=8-16',
#  'https://www.amazon.in/HP-Laptop-14-inch-Natural-14s-er0503TU/dp/B098393BRS/ref=sr_1_17?keywords=laptop&qid=1639377407&sr=8-17',
#  'https://www.amazon.in/HP-ProBook-Bluetooth-Integrated-Graphics/dp/B09LRZB2HN/ref=sr_1_18?keywords=laptop&qid=1639377407&sr=8-18',
#  'https://www.amazon.in/Acer-Processor-Business-Integrated-EX215-31/dp/B095BYNN8Z/ref=sr_1_19?keywords=laptop&qid=1639377407&sr=8-19',
#  'https://www.amazon.in/HP-Chromebook-14-inch-Touchscreen-14a-cb0006AU/dp/B09CMNZ4T1/ref=sr_1_20?keywords=laptop&qid=1639377407&sr=8-20',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg1_1?ie=UTF8&adId=A03659901A9PII22BSKN3&url=%2FHP-Laptop-inches-Windows-15s-du1516TU%2Fdp%2FB095YC5VH4%2Fref%3Dsr_1_21_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-21-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_btf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg1_1?ie=UTF8&adId=A0408528GPIEOUAB2QO0&url=%2FLenovo-ThinkPad-Laptop-39-62cm-20TDS0RP00%2Fdp%2FB09GB39FK5%2Fref%3Dsr_1_22_sspa%3Fkeywords%3Dlaptop%26qid%3D1639377407%26sr%3D8-22-spons%26psc%3D1&qualifier=1639377407&id=664843759642431&widgetName=sp_btf']

# %%
brand=[]
name=[]
rating=[]
nor=[]
price=[]
exchg=[]
expdelivery=[]
avail=[]
details=[]

# %%
for i in url:
    driver.get(i)
    try:
        b=driver.find_element_by_xpath("//tr[2][@class='a-spacing-small']/td[2]/span[1]")
        brand.append(b.text)
    except:
        brand.append('-')
    try:
        n=driver.find_element_by_xpath("//span[@class='a-size-large product-title-word-break']")
        name.append(n.text)
    except:
        name.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        rat=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        rating.append(rat.text)
    except:
        rating.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        no=driver.find_element_by_xpath("//div[@class='a-row a-spacing-medium averageStarRatingNumerical']/span")
        nor.append(no.text)
    except:
        nor.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        p=driver.find_element_by_xpath("//td[@class='a-span12']/span[1]")
        price.append(p.text)
    except:
        price.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        ex=driver.find_element_by_xpath("//div[@class='a-row icon-farm-wrapper']/div[1]/span[1]/div[2]/a")
        exchg.append(ex.text)
    except:
        exchg.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        de=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
        expdelivery.append(de.text)
    except:
        expdelivery.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        av=driver.find_element_by_xpath("//div[@class='a-section a-spacing-base }']/span[1]")
        avail.append(av.text)
    except:
        avail.append('-')

# %%
for i in url:
    driver.get(i)
    try:
        d=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']")
        details.append(d.text)
    except:
        details.append('-')

# %%
print(len(brand))
print(len(name))
print(len(price))
print(len(rating))
print(len(nor))
print(len(exchg))
print(len(expdelivery))
print(len(avail))
print(len(details))
# Out:
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26

# %%
laptop=pd.DataFrame({})
laptop['brand']=brand
laptop['name']=name
laptop['rating']=rating
laptop['nor']=nor
laptop['price']=price
laptop['exchg']=exchg
laptop['expdelivery']=expdelivery
laptop['avail']=avail
laptop['details']=details
laptop['url']=url
laptop
# Out:
#       brand                                               name        rating  \
# 0      Acer  Acer Nitro 5 AN515-57 Gaming Laptop | Intel Co...  4.1 out of 5
# 1   Fujitsu  Fujitsu UH-X 11th Gen Intel Core i5 13.3 inche...  4.1 out of 5
# 2      ASUS  ASUS VivoBook 15 (2020), 39.6 cm HD, Dual Core...  4.2 out of 5
# 3      Dell  Dell Vostro 3405 14" (35.56cms) HD AG Display ...  3.7 out of 5
# 4    Lenovo  Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...    4 out of 5
# 5    Lenovo  Lenovo IdeaPad Slim 5 Pro 11th Gen Intel Core ...  4.2 out of 5
# 6      ASUS  ASUS ZenBook 14 UX433FA-A6106T 8th Gen Intel C...    4 out of 5
# 7      Acer  Acer Swift 3 AMD Ryzen 5 4500U 14" (35.56cms) ...  4.2 out of 5
# 8        HP  HP 15 (2021) Thin & Light Ryzen 3-3250 Laptop,...  3.9 out of 5
# 9     AVITA  AVITA Cosmos 2 in 1 Celeron Dual Core - (4 GB/...  3.6 out of 5
# 10       HP  HP Chromebook 14-inch (35.56 cms) Thin & Light...  3.7 out of 5
# 11     Dell  Dell 15 (2021) Ryzen 3-3250U Laptop, 8GB DDR4,...  2.9 out of 5
# 12       HP  HP 15 10th Gen Intel Core i3 Thin and Light 15...  3.9 out of 5
# 13   Lenovo  Lenovo IdeaPad 3 Intel Celeron N4020 14'' HD T...  4.1 out of 5
# 14       HP  HP Pavilion (2021) Intel 11th Gen Core i5 14 i...  4.4 out of 5
# 15       HP  HP 15 Ryzen 3 Thin & Light 15.6-inch (39.6 cms...  4.1 out of 5
# 16     Dell  Dell 15 (2021) Athlon Silver 3050U Laptop, 4GB...  3.9 out of 5
# 17       HP  HP 15s 11th Gen Intel Core i3 15.6 inches Busi...  4.1 out of 5
# 18       HP  HP Chromebook Intel Celeron N4020 14 inches To...  3.9 out of 5
# 19       HP  HP 15 Ryzen 3 Thin & Light 15.6-inch (39.6 cms...  4.1 out of 5
# 20       HP  HP 14(2021) 10th Gen Intel Core i5 Laptop, 8GB...  4.8 out of 5
# 21       HP  (Renewed) HP ProBook 430 G1 13.3 inch (33.8 cm...             -
# 22     Acer  Acer Extensa 15 Thin & Light Intel Processor P...  3.6 out of 5
# 23       HP  HP Chromebook x360 14-inch (35.56 cms) Thin & ...  4.1 out of 5
# 24       HP  HP 15 (2021) Thin & Light 10th Gen Intel Core ...  4.1 out of 5
# 25   Lenovo  Lenovo ThinkPad E15 Intel Core i3 11th Gen 15....  4.6 out of 5
#
#                      nor       price               exchg       expdelivery  \
# 0     380 global ratings  ₹76,990.00  7 Days Replacement    Friday, Dec 17
# 1      33 global ratings  ₹59,990.00  7 Days Replacement  Thursday, Dec 16
# 2     843 global ratings           -  7 Days Replacement                 -
# 3      41 global ratings  ₹29,990.00                   -         Jan 4 - 9
# 4     136 global ratings  ₹30,489.00  7 Days Replacement    Sunday, Dec 19
# 5     106 global ratings  ₹73,890.00  7 Days Replacement  Thursday, Dec 16
# 6      40 global ratings  ₹72,999.00  7 Days Replacement  Saturday, Dec 18
# 7      73 global ratings  ₹63,990.00  7 Days Replacement    Sunday, Dec 19
# 8   2,030 global ratings  ₹38,990.00  7 Days Replacement  Saturday, Dec 18
# 9     118 global ratings  ₹15,980.00                   -  Saturday, Dec 18
# 10    816 global ratings  ₹25,490.00                   -  Thursday, Dec 16
# 11      5 global ratings  ₹36,890.00  7 Days Replacement  Thursday, Dec 16
# 12  2,027 global ratings  ₹38,990.00  7 Days Replacement  Thursday, Dec 16
# 13    443 global ratings  ₹29,490.00                   -  Thursday, Dec 16
# 14  1,583 global ratings  ₹66,990.00  7 Days Replacement  Thursday, Dec 16
# 15    162 global ratings  ₹38,490.00  7 Days Replacement  Thursday, Dec 16
# 16     15 global ratings  ₹34,990.00  7 Days Replacement    Sunday, Dec 19
# 17    186 global ratings  ₹44,870.00  7 Days Replacement  Thursday, Dec 16
# 18    277 global ratings  ₹25,990.00                   -  Thursday, Dec 16
# 19    162 global ratings  ₹38,490.00  7 Days Replacement  Thursday, Dec 16
# 20      7 global ratings  ₹54,990.00  7 Days Replacement    Friday, Dec 17
# 21                     -  ₹28,999.00  7 Days Replacement                 -
# 22    342 global ratings           -  7 Days Replacement                 -
# 23    130 global ratings  ₹29,990.00                   -  Thursday, Dec 16
# 24    186 global ratings  ₹43,855.00  7 Days Replacement    Friday, Dec 17
# 25      8 global ratings  ₹43,990.00  7 Days Replacement    Monday, Dec 20
#
#    avail                                            details  \
# 0      -  Dominate the Game: Great performance meets lon...
# 1      -  Build : Made in Japan | Built with Takumi craf...
# 2         Free upgrade to Windows 11 when available. Dis...
# 3      -  Processor: AMD Athlon Silver 3050U Mobile Proc...
# 4      -  Free upgrade to Windows 11 when available* Dis...
# 5      -  Free upgrade to Windows 11 when available* Dis...
# 6      -  Processor: 8th Gen Intel Core i5-8265U process...
# 7      -  Processor : AMD Ryzen 5 4500U hexa-core proces...
# 8      -  Free upgrade to Windows 11 when available* Dis...
# 9      -  This 2-in-1 laptop comes with a detachable key...
# 10     -  GOOGLE ASSISTANT: Voice-Enabled Google Assista...
# 11     -  Free upgrade to Windows 11 when available. Dis...
# 12     -  Free upgrade to Windows 11 when available* Dis...
# 13     -  Processor: 4th Gen Intel Celeron N4020 | Speed...
# 14     -  Processor: 11th Gen Intel Core i5-1135G7 (up t...
# 15     -  Free upgrade to Windows 11 when available* Dis...
# 16     -  Free upgrade to Windows 11 when available. Dis...
# 17     -  Processor: 11th Gen Intel Core i3- 1125G4 (up ...
# 18     -  1.1GHz Intel Celeron N4020 processor\n4GB DDR4...
# 19     -  Free upgrade to Windows 11 when available* Dis...
# 20     -  Free upgrade to Windows 11 when available* Dis...
# 21     -  HP ProBook gives fast performance at an afford...
# 22        𝗙𝗮𝘀𝘁 𝗮𝗻𝗱 𝗘𝗮𝘀𝘆 𝗖𝗼𝗺𝗽𝘂𝘁𝗶𝗻𝗴 :Perfect budget laptop...
# 23     -  Google Assistant: Voice-Enabled Google Assista...
# 24     -  Free upgrade to Windows 11 when available* Dis...
# 25     -  ThinkPad Reliability tested on 12 MIL-STD-810H...
#
#                                                   url
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/ASUS-VivoBook-Integrated...
# 3   https://www.amazon.in/Dell-35-56cms-Integrated...
# 4   https://www.amazon.in/Lenovo-IdeaPad-Celeron-P...
# 5   https://aax-eu.amazon.in/x/c/QpCnX5ulXk0UIupRW...
# 6   https://www.amazon.in/ZenBook-UX433FA-A6106T-i...
# 7   https://www.amazon.in/Acer-14-inch-Display-Gra...
# 8   https://www.amazon.in/HP-3-3250-Laptop-Windows...
# 9   https://www.amazon.in/AVITA-Cosmos-Celeron-Dua...
# 10  https://www.amazon.in/HP-Chromebook-14a-na0003...
# 11  https://www.amazon.in/Dell-Graphics-Inspiron-3...
# 12  https://www.amazon.in/HP-inches-Laptop-Windows...
# 13  https://www.amazon.in/Lenovo-IdeaPad-Celeron-P...
# 14  https://www.amazon.in/gp/slredirect/picassoRed...
# 15  https://www.amazon.in/gp/slredirect/picassoRed...
# 16  https://www.amazon.in/Dell-Graphics-Inspiron-3...
# 17  https://www.amazon.in/HP-inches-Business-Windo...
# 18  https://www.amazon.in/HP-Chromebook-14a-na0002...
# 19  https://www.amazon.in/HP-15-6-inch-Laptop-Wind...
# 20  https://www.amazon.in/HP-Laptop-14-inch-Natura...
# 21  https://www.amazon.in/HP-ProBook-Bluetooth-Int...
# 22  https://www.amazon.in/Acer-Processor-Business-...
# 23  https://www.amazon.in/HP-Chromebook-14-inch-To...
# 24  https://www.amazon.in/gp/slredirect/picassoRed...
# 25  https://www.amazon.in/gp/slredirect/picassoRed...

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
# importing required libraries.
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests

# %%
#connecting the web driver.
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
#getting the google images website
driver.get('https://images.google.com')

# %%
#finding the search bar and filling the image name 
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("fruits")

# %%
#finding the search button and clicking
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")

# %%
#creating empty list
img_fruits= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_fruits.append(images.get('src'))
        except NoSuchElementException:
            img_fruits.append('-')

# %%
#getting the google images website
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")
driver.get('https://images.google.com')

# %%
#finding the search bar and filling the image name 
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("cars")

# %%
#finding the search button and clicking
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")

# %%
#creating empty list
img_cars= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_cars.append(images.get('src'))
        except NoSuchElementException:
            img_cars.append('-')

# %%
#getting the google images website
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")
driver.get('https://images.google.com')

# %%
#finding the search bar and filling the image name 
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("Machine Learning")

# %%
#finding the search button and clicking
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")

# %%
#creating empty list
img_ML= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_ML.append(images.get('src'))
        except NoSuchElementException:
            img_ML.append('-')

# %%
Google_images=pd.DataFrame({})
Google_images["100_Img_Fruits"]=img_fruits[0:100]
Google_images["100_Img_Cars"]=img_cars[0:100]
Google_images["100_Img_ML"]=img_ML[0:100]
Google_images
# Out:
#                                        100_Img_Fruits  \
# 0   /images/branding/searchlogo/1x/googlelogo_desk...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                          100_Img_Cars  \
# 0   /images/branding/searchlogo/1x/googlelogo_desk...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                            100_Img_ML
# 0   /images/branding/searchlogo/1x/googlelogo_desk...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [100 rows x 3 columns]

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import selenium
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
#first connect to web driver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
#close log_in window
log_in_pop_up = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
log_in_pop_up.click()

# %%
#locating the search bar
search_bar=driver.find_element_by_class_name("_3704LK")

# %%
##search for  redmi note 10s
search_bar.send_keys('REDMI Note 10S')
button=driver.find_element_by_class_name('L0Z3Pu')

##click searc icon
button.click()

# %%
# creating empty lists for scraping data
brand=[]
desc=[]
price=[]
discount=[]
battery=[]
camera=[]
processor=[]

# %%
##scraping the brand name, url and price of product
brand_list=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
url_list=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']")
price_list=driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")

# %%
##scraping text from web elements
for i in url_list[0:30]:
    try:
        discount_list=driver.find_element_by_xpath("//div[@class='_3Ay6Sb']//span[1]")
        discount.append(discount_list.text)
    except:
        discount[i].append("-")

# %%
##scraping description of product
try:
    desc_list=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']")
    for i in desc_list:
        desc.append(i.text)
except:
    desc.append("-")

# %%
##scraping camera details of product
try:
    camera_list=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']//li[3]")
    for i in camera_list:
        camera.append(i.text)
except:
    camera.append("-")

# %%
##scraping battry details of product
try:
    battery_list=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']//li[4]")
    for i in battery_list:
        battery.append(i.text)
except:
    battery.append("-")

# %%
##scraping processor details of product
try:
    processor_list=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']//li[5]")
    for i in processor_list:
        processor.append(i.text)
except:
    battery.append("-")

# %%
##striping unneccessary details and appending data to list
for i in price_list:
    price.append(i.text.strip())
for i in brand_list:
    brand.append(i.text)

# %%
##creating data frame
data=pd.DataFrame({'Name':brand,'discount':discount,'price':price,'RAM|ROM|display_size':desc,'Battery':battery,'camera':camera,'processor':processor})

# %%
data
# Out:
#                                                Name discount    price  \
# 0               REDMI Note 10S (Frost White, 64 GB)   4% off  ₹15,339
# 1             REDMI Note 10S (Deep Sea Blue, 64 GB)   4% off  ₹15,590
# 2              REDMI Note 10S (Shadow Black, 64 GB)   4% off  ₹15,470
# 3             REDMI Note 10S (Shadow Black, 128 GB)   4% off  ₹17,490
# 4              REDMI Note 10S (Frost White, 128 GB)   4% off  ₹17,497
# 5            REDMI Note 10S (Deep Sea Blue, 128 GB)   4% off  ₹19,717
# 6            REDMI Note 10S (Cosmic Purple, 128 GB)   4% off  ₹17,185
# 7            REDMI Note 10S (Deep Sea Blue, 128 GB)   4% off  ₹17,189
# 8              REDMI Note 10S (Frost White, 128 GB)   4% off  ₹18,999
# 9             REDMI Note 10S (Shadow Black, 128 GB)   4% off  ₹18,999
# 10           REDMI Note 10S (Cosmic Purple, 128 GB)   4% off  ₹20,990
# 11          REDMI M2101K7BI (Cosmic Purple, 128 GB)   4% off  ₹15,749
# 12        REDMI Note 10T 5G (Graphite Black, 64 GB)   4% off  ₹16,488
# 13      REDMI NOTE 10 LITE (Champagne Gold, 128 GB)   4% off  ₹17,480
# 14       REDMI NOTE 10 LITE (Glacier White, 128 GB)   4% off  ₹15,970
# 15  REDMI Note 10 Lite (Interstellar Black, 128 GB)   4% off  ₹15,228
# 16       REDMI Note 10T 5G (Chromium White, 128 GB)   4% off  ₹18,990
# 17       REDMI Note 10 Lite (Glacier White, 128 GB)   4% off  ₹16,945
# 18       REDMI Note 10 Pro (Vintage Bronze, 128 GB)   4% off  ₹20,899
# 19        REDMI Note 10T 5G (Metallic Blue, 128 GB)   4% off  ₹18,985
# 20         REDMI Note 10T 5G (Metallic Blue, 64 GB)   4% off  ₹16,795
# 21         REDMI NOTE 10 LITE (Aurora Blue, 128 GB)   4% off  ₹16,819
# 22         REDMI Note 10 Pro (Glacial Blue, 128 GB)   4% off  ₹20,890
# 23           REDMI Note 10 Pro (Dark Night, 128 GB)   4% off  ₹20,719
#
#                                  RAM|ROM|display_size  \
# 0   6 GB RAM | 64 GB ROM\n16.33 cm (6.43 inch) Ful...
# 1   6 GB RAM | 64 GB ROM\n16.33 cm (6.43 inch) Ful...
# 2   6 GB RAM | 64 GB ROM\n16.33 cm (6.43 inch) Ful...
# 3   6 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 4   6 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 5   8 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 6   6 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 7   6 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 8   8 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 9   8 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 10  8 GB RAM | 128 GB ROM\n16.26 cm (6.4 inch) Dis...
# 11  6 GB RAM | 128 GB ROM\n16.33 cm (6.43 inch) Fu...
# 12  4 GB RAM | 64 GB ROM\n16.51 cm (6.5 inch) Full...
# 13  6 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 14  4 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 15  4 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 16  6 GB RAM | 128 GB ROM\n16.51 cm (6.5 inch) Ful...
# 17  6 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 18  8 GB RAM | 128 GB ROM | Expandable Upto 512 GB...
# 19  6 GB RAM | 128 GB ROM\n16.51 cm (6.5 inch) Ful...
# 20  4 GB RAM | 64 GB ROM\n16.51 cm (6.5 inch) Full...
# 21  6 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 22  8 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
# 23  8 GB RAM | 128 GB ROM\n16.94 cm (6.67 inch) Di...
#
#                         Battery                                      camera  \
# 0              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 1              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 2              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 3              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 4              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 5              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 6              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 7              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 8              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 9              5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 10             5000 mAh Battery                            64MP Rear Camera
# 11             5000 mAh Battery  64MP + 8MP + 2MP + 2MP | 13MP Front Camera
# 12             5000 mAh Battery         48MP + 2MP + 2MP | 8MP Front Camera
# 13             5020 mAh Battery                            48MP Rear Camera
# 14             5020 mAh Battery                            48MP Rear Camera
# 15             5020 mAh Battery                            48MP Rear Camera
# 16             5000 mAh Battery         48MP + 2MP + 2MP | 8MP Front Camera
# 17             5020 mAh Battery                            48MP Rear Camera
# 18  5020 mAh Li-Polymer Battery  64MP + 8MP + 5MP + 2MP | 16MP Front Camera
# 19             5000 mAh Battery         48MP + 2MP + 2MP | 8MP Front Camera
# 20             5000 mAh Battery         48MP + 2MP + 2MP | 8MP Front Camera
# 21             5020 mAh Battery                            48MP Rear Camera
# 22             5020 mAh Battery                            64MP Rear Camera
# 23             5020 mAh Battery                            64MP Rear Camera
#
#                                             processor
# 0                        MediaTek Helio G95 Processor
# 1                        MediaTek Helio G95 Processor
# 2                        MediaTek Helio G95 Processor
# 3                        MediaTek Helio G95 Processor
# 4                        MediaTek Helio G95 Processor
# 5                        MediaTek Helio G95 Processor
# 6                        MediaTek Helio G95 Processor
# 7                        MediaTek Helio G95 Processor
# 8                        MediaTek Helio G95 Processor
# 9                        MediaTek Helio G95 Processor
# 10                                    1 Year Warranty
# 11                       MediaTek Helio G95 Processor
# 12                   MediaTek Dimensity 700 Processor
# 13                       1 Year Manufacturer Warranty
# 14                                          12 months
# 15                       1 Year Manufacturer Warranty
# 16                   MediaTek Dimensity 700 Processor
# 17                       1 Year Manufacturer Warranty
# 18                 Qualcomm Snapdragon 732G Processor
# 19                   MediaTek Dimensity 700 Processor
# 20                   MediaTek Dimensity 700 Processor
# 21                       1 Year Manufacturer Warranty
# 22  1 year manufacturer warranty for device and 6 ...
# 23  1 year manufacturer warranty for device and 6 ...

# %%
##saving as csv file
data.to_csv('mobile_info.csv')

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import pandas as pd
import selenium
from selenium import webdriver
import re

# %%
#connecting the web driver.
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
#getting the required url
driver.get('https://www.google.com/maps')

# %%
#finding the search bar and filling the city name
search_bar = driver.find_element_by_xpath('//input[@class="tactile-searchbox-input"]')    
search_bar.clear()                                               
search_bar.send_keys(input('Enter the city name: \n\n'))
# Out:
# Enter the city name:
#
# pune

# %%
#finding the search button and clicking
search_button = driver.find_element_by_xpath('//button[@id="searchbox-searchbutton"]')       
search_button.click()

# %%
#getting the current url
Location=driver.current_url

# %%
#finding the latitude and longitude using regex
coordinates=re.findall(r'@(.*)data',Location)
coordinates
lat_lon=coordinates[0].split(",")
lat=lat_lon[0]
lon=lat_lon[1]
print("\nlatitude={},longitude={}".format(lat,lon))
# Out:
# latitude=23.1636992,longitude=79.9178752

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
# importing required libraries.
import pandas as pd
import selenium
from selenium import webdriver

# %%
#connecting the web driver.
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
#getting the required url
driver.get('https://www.trak.in')

# %%
# getting xpath for funding deals and clicking on the button
fund_button = driver.find_element_by_xpath("//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(fund_button)

# %%
#Empty Lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry/Vertical'] = []
fund_deals['Sub_Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []

# %%
# getting xpath for funding deals and clicking on the button
fund_button = driver.find_element_by_xpath("//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(fund_button)

# %%
#Empty Lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry/Vertical'] = []
fund_deals['Sub_Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []

# %%
for i in range(48,51):
    
    # scraping data of data
    date = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[2]".format(i))
    for d in date:
        fund_deals['Date'].append(d.text)

# %%
for i in range(48,51):
     # scraping data of startup name
    startup_name = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[3]".format(i))
    for name in startup_name:
        fund_deals['Startup Name'].append(name.text)

# %%
for i in range(48,51):
#scraping data of industry or vertical
    industry = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[4]".format(i))
    for ind in industry:
        fund_deals['Industry/Vertical'].append(ind.text)

# %%
for i in range(48,51):
#scraping data of sub-vertical
    sub_vertical = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[5]".format(i))
    for sv in sub_vertical:
        fund_deals['Sub_Vertical'].append(sv.text)

# %%
for i in range(48,51):
# scraping data of location
    location = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[6]".format(i))
    for loc in location:
        fund_deals['Location'].append(loc.text)

# %%
for i in range(48,51):
# scraping data of investor
    investor = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[7]".format(i))
    for invest in investor:
        fund_deals['Investor'].append(invest.text)

# %%
for i in range(48,51):
# scraping data of investment type
    investment_type = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[8]".format(i))
    for invtype in investment_type:
        fund_deals['Investment Type'].append(invtype.text)

# %%
for i in range(48,51):
# scraping data of amount
    amount = driver.find_elements_by_xpath("//table[@id='tablepress-{}']/tbody/tr/td[9]".format(i))
    for amt in amount:
        fund_deals['Amount(in USD)'].append(amt.text)

# %%
# checking lengths of all scraped data
print(len(fund_deals['Date']),
len(fund_deals['Startup Name']),
len(fund_deals['Industry/Vertical']),
len(fund_deals['Sub_Vertical']),
len(fund_deals['Location']),
len(fund_deals['Investor']),
len(fund_deals['Investment Type']),
len(fund_deals['Amount(in USD)'] 
))
# Out:
# 30 30 30 30 30 30 30 30

# %%
#creating DataFrame for scraped data
fund_data = pd.DataFrame(fund_deals)
fund_data
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub_Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
# opening the url digit.in
url = "https://www.digit.in/"
driver.get(url)

# %%
# searching for best Laptop
best_gam_laptops = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()

# %%
# creating empty list
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Graph_proc = []
Price = []

# %%
#scraping the data of laptop names
laptop_name = driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)

# %%
#scraping the data of operating system
try:
    op_sys = driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass

# %%
#scraping data of display of the Laptop
try:
    display = driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass

# %%
# scraping data of processor
try:
    processor = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

# %%
# scraping the data of memory
try:
    memory = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass

# %%
# scraping data of weight
try:
    weight = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass

# %%
# scraping data of dimensions
try:
    dimension = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass

# %%
# scraping data of graph processor
try:
    graph = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]")
    for gra in graph:
        Graph_proc.append(gra.text)
except NoSuchElementException:
    pass

# %%
# scraping the data of price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹ ','Rs'))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),
len(Operating_sys),
len(Display),
len(Processor),
len(Memory),
len(Weight),
len(Dimensions),
len(Graph_proc),
len(Price))
# Out:
# 10 10 10 10 10 10 10 10 10

# %%
#creating DataFrame for scraped data
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating System'] =Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Weight'] = Weight
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Graphical Processor'] = Graph_proc
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                                      Laptop Name Operating System  \
# 0                    ACER NITRO 5 RYZEN 9 (2021)       WINDOWS 10
# 1  MSI STEALTH 15M 11TH GEN CORE I7-11375H (2021       WINDOWS 10
# 2   ASUS ROG STRIX SCAR 15 RYZEN 9-5900HX (2021)       WINDOWS 10
# 3                          ALIENWARE AREA 51M R2  WINDOWS 10 HOME
# 4                               ALIENWARE M15 R3  WINDOWS 10 HOME
# 5                         ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME
# 6                          ASUS ROG ZEPHYRUS G14  WINDOWS 10 HOME
# 7                               LENOVO LEGION 5I   WINDOWS 10 PRO
# 8                       ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10
# 9                           ACER ASPIRE 7 GAMING  WINDOWS 10 HOME
#
#                Display                                   Processor  \
# 0  15.6" (1920 X 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 X 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 X 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 X 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 X 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 X 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 X 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 X 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 X 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 X 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#                    Memory Weight               Dimensions  \
# 0   1 TB HDD/16 GBGB DDR4    2.4       363.4 x 255 x 23.9
# 1   1 TB SSD/16 GBGB DDR4    1.7      358.3 x 248 x 16.15
# 2   2 TB SSD/32 GBGB DDR4   2.30         354 x 259 x 22.6
# 3   1 TB SSD/16 GBGB DDR4    4.1   27.65 x 402.6 x 319.14
# 4   1 TB SSD/16 GBGB DDR4     NA                       NA
# 5   1 TB SSD/16 GBGB DDR4   2.30       35.4 x 25.9 x 2.26
# 6   1 TB SSD/16 GBGB DDR4   1.65        32.5 x 22.1 x 1.8
# 7   1 TB SSD/16 GBGB DDR4    2.3  363.06 x 259.61 x 23.57
# 8  512 GB SSD/4 GBGB DDR4    2.4  268.30 x 360.00 x 20.90
# 9  512 GB SSD/8 GBGB DDR4   2.15       2.29 x 36.3 x 25.4
#
#              Graphical Processor      Price
# 0        NVIDIA GeForce RTX 3070  Rs129,990
# 1        NVIDIA GeForce RTX 3060  Rs134,990
# 2        NVIDIA GeForce RTX 3080  Rs268,990
# 3        Intel® UHD Graphics 630  Rs342,989
# 4                             NA  Rs319,990
# 5      NVIDIA® GeForce RTX™ 3070  Rs215,990
# 6        NVIDIA GeForce RTX 2060  Rs164,990
# 7  NVIDIA® GeForce® GTX 1650 4GB   Rs76,988
# 8  NVIDIA GeForce RTX 2070 Max-Q  Rs185,000
# 9      NVIDIA® GeForce® GTX 1650   Rs58,990

# %%
# saving the data to csv
Gaming_Laptop.to_csv("Gaming_Laptops.csv")

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import selenium
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
# connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
##open frobes window
url ="https://www.forbes.com/"
driver.get(url)

# %%
##clicking on menu
button= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[1]/button[1]")
button.click()

# %%
##selecting billionaire
b_link = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/a")
b_link.click()

# %%
##selecting world billionaire table
top = driver.find_element_by_xpath("/html/body/div[1]/main/div/section/section[1]/div/div/div[1]/div/div[1]/div[1]/div[2]/a")
top.click()

# %%
# creating empty lists for scraping data
rank1=[]
name=[]
net=[]
age=[]
citi=[]
src=[]
Industry=[]

# %%
#scraping the data
rank_l=driver.find_elements_by_xpath("//div[@class='rank']")
for i in rank_l:
    if i.text is None :
        rank1.append("--") 
    else:
        rank1.append(i.text)

# %%
name_l=driver.find_elements_by_xpath("//div[@class='personName']")
for i in name_l:
    if i.text is None :
        name.append("--") 
    else:
        name.append(i.text)

# %%
net_l=driver.find_elements_by_xpath("//div[@class='netWorth']")
for i in net_l:
    if i.text is None :
        net.append("--") 
    else:
        net.append(i.text)

# %%
age_l=driver.find_elements_by_xpath("//div[@class='age']")
for i in age_l:
    if(i.text is None):
        age.append("--") 
    else:
        age.append(i.text)

# %%
citi_l=driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
for i in citi_l:
    if i.text is None :
        citi.append("--") 
    else:
        citi.append(i.text)

# %%
src_l=driver.find_elements_by_xpath("//div[@class='source']")
for i in src_l:
    if i.text is None :
        src.append("--") 
    else:
        src.append(i.text)

# %%
ind_l=driver.find_elements_by_xpath("//div[@class='category']")
for i in ind_l:
    if i.text is None :
        Industry.append("--") 
    else:
        Industry.append(i.text)

# %%
##save as dataframe
df=pd.DataFrame({"Rank":rank1,"Name":name,"Networth":net,"Age":age,"citizenship":citi,"source":src,"Industry":Industry})

# %%
df
# Out:
#      Rank                      Name Networth Age    citizenship  \
# 0      1.                Jeff Bezos   $177 B  57  United States
# 1      2.                 Elon Musk   $151 B  49  United States
# 2      3.  Bernard Arnault & family   $150 B  72         France
# 3      4.                Bill Gates   $124 B  65  United States
# 4      5.           Mark Zuckerberg    $97 B  36  United States
# ..    ...                       ...      ...  ..            ...
# 195  195.           Harry Triguboff  $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family  $11.1 B  65         Russia
# 197  197.                 Eyal Ofer  $11.1 B  70         Israel
# 198  197.              Evan Spiegel  $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento    $11 B  88       Colombia
#
#                     source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %%
##save as csv file
df.to_csv('billionaires_list.csv')

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
import selenium
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
# connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
url = "https://www.youtube.com/"
driver.get(url)

# %%
# finding element for search bar
search_bar = driver.find_element_by_xpath("//div[@class='ytd-searchbox-spt']/input")
search_bar.send_keys("anime")

# %%
#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")
search_btn.click()

# %%
# clicking on first video
video = driver.find_element_by_xpath("//yt-formatted-string[@class='style-scope ytd-video-renderer']")
video.click()

# %%
# 1000 times we scroll down by 10000 in order to generate more comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
# creating empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# %%
# scrape comments
cm = driver.find_elements_by_id("content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)

# %%
# scrape time when comment was posted
tm = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)
    
for i in range(0,len(Time),2):
    comment_time.append(Time[i])

# %%
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
print(len(comments),len(comment_time),len(No_of_Likes))
# Out:
# 630 630 630

# %%
# creating dataframe for scraped data

Youtube = pd.DataFrame({})
Youtube['Comment'] = comments[:500]
Youtube['Comment Time'] = comment_time[:500]
Youtube['Comment Upvotes'] = No_of_Likes[:500]
Youtube
# Out:
#                                                Comment           Comment Time  \
# 0    Rudy didn't cry when he was welcomed into that...           13 hours ago
# 1    I'll miss Ruijerd so much , the time he spent ...            5 hours ago
# 2    "Part of the journey is the end."\n"It's about...   2 hours ago (edited)
# 3    The usage of opening 1 is nothing short of an ...            5 hours ago
# 4    In case no one noticed... Rudeus' line as they...   5 hours ago (edited)
# ..                                                 ...                    ...
# 495                                 Let's go ED Arc!!!           13 hours ago
# 496  Can't wait to see Rudeus grown up and becomes ...  13 hours ago (edited)
# 497                                     spoiler alert:   5 hours ago (edited)
# 498  this episode have touch my emotion and feeling...            5 hours ago
# 499     That was unexpected and very sad in the end...            2 hours ago
#
#     Comment Upvotes
# 0              2.7K
# 1               691
# 2                99
# 3               353
# 4               506
# ..              ...
# 495               1
# 496               2
# 497
# 498
# 499
#
# [500 rows x 3 columns]

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
import selenium
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
# connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\WIN-10\Downloads\chromedriver.exe")

# %%
# getting the web page of mentioned url
driver.get('https://www.hostelworld.com')

# %%
searchbtn=driver.find_element_by_xpath("//input[@class='location-text']")
searchbtn.click()

# %%
searchjob=driver.find_element_by_xpath("//input[@id='search-input-field']")
searchjob.send_keys('London')

# %%
searcbtn=driver.find_element_by_xpath("//ul[@id='predicted-search-results']/li[2]/div")
searcbtn.click()

# %%
gobtn=driver.find_element_by_xpath("//button[@id='search-button']")
gobtn.click()

# %%
# creating empty list & find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description = []
url = []

# %%
# scraping the required informations
for i in driver.find_elements_by_xpath("//div[@class='pagination-item pagination-current' or @class='pagination-item']"):
    i.click()

# %%
# scraping  hostel name
try:
    name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
    for i in name:
        hostel_name.append(i.text)
except NoSuchElementException:
        hostel_name.append('-')

# %%
# scraping distance from city centre
try:
    dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
    for i in name:
        distance.append(i.text.replace('Hostel - ',''))
except NoSuchElementException:
        distance.append('-')

# %%
# scraping privates from price
for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):   
    try:
        pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
        pvt_prices.append(pvt_price.text)
    except NoSuchElementException:
            pvt_prices.append('-')

# %%
# scraping dorms from price
for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
    try:
        dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]/div")
        dorms_price.append(dorms.text)
    except NoSuchElementException:
        dorms_price.append('-')

# %%
# scraping facilities
try:
    fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
    fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
    for i in fac1:
        for j in fac2:
            facilities.append(i.text +', '+ j.text)
except NoSuchElementException:
    facilities.append('-')

# %%
#fetching url of each hostel
p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
for i in p_url:
    url.append(i.get_attribute("href"))

# %%
for i in url:
    driver.get(i)

# %%
# scraping ratings
try:
    rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
    rating.append(rat.text)
except NoSuchElementException:
    rating.append('-')

# %%
# scraping total review
try:
    rws = driver.find_element_by_xpath("//div[@class='reviews']")
    reviews.append(rws.text.replace('Total Reviews',''))
except NoSuchElementException:
    reviews.append('-')

# %%
# fetching over all review
try:
    overall = driver.find_element_by_xpath("//div[@class='keyword']//span")
    over_all.append(overall.text)
except NoSuchElementException:
    over_all.append('-')

# %%
# fetching property description
try:
    disc = driver.find_element_by_xpath("//div[@class='content']")
    description.append(disc.text)
except NoSuchElementException:
    over_all.append('-')

# %%
# do click on show more button for description
try:
    driver.find_element_by_xpath("//a[@class='toggle-content']").click()
except NoSuchElementException:
    pass

# %%
print(len(hostel_name),
len(distance),
len(pvt_prices),
len(dorms_price),
len(rating),
len(reviews),
len(over_all),
len(facilities),
len(description),
len(url))
# Out:
# 29 29 29 29 1 1 1 110 1 29

# %%
# creating DataFrame
Hostel = pd.DataFrame({})
Hostel['Hostel Name'] = hostel_name
Hostel['Distance from City Centre'] = distance
Hostel['Ratings'] = rating
Hostel['Total Reviews'] = reviews
Hostel['Overall Reviews'] = over_all
Hostel['Privates from Price'] = pvt_prices
Hostel['Dorms from Price'] = dorms_price
Hostel['Facilities'] = facilities
Hostel['Description'] = description
Hostel
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-3bf22405dafa> in <module>
#       3 Hostel['Hostel Name'] = hostel_name
#       4 Hostel['Distance from City Centre'] = distance
# ----> 5 Hostel['Ratings'] = rating
#       6 Hostel['Total Reviews'] = reviews
#       7 Hostel['Overall Reviews'] = over_all
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
